# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshasinghrajput-png/Basics-of-Python/blob/main/The_Greeting_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Greeting Bot!**

# %%
name = input("Please enter your name: ")
color = input("Please enter your favourite color: ")

print("Hello! ", name)
print("I see your favourite color is ", color)
# Out:
# Please enter your name: Samiksha Singh R
# Please enter your favourite color: Blue
# Hello!  Samiksha Singh R
# I see your favourite color is  Blue
