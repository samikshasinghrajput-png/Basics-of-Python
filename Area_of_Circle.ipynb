# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshasinghrajput-png/Basics-of-Python/blob/main/Area_of_Circle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Area of a Circle

# %%
r = float(input("Enter the radius of the circle:"))
area = 3.14 * r * r
print(area)
# Out:
# Enter the radius of the circle:3.76
# 44.392064
