# %% [markdown]
# <a href="https://colab.research.google.com/github/samikshasinghrajput-png/Basics-of-Python/blob/main/Temperature_Converter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Temperature Converter**

# %%
celsius_value = float(input("Please enter the temperature in celsius: "))
F = (celsius_value * 9/5)+32
print("The tempearture in fahrenheit is ", F)
# Out:
# Please enter the temperature in celsius: 32.5
# The tempearture in fahrenheit is  90.5
